# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt

from skimage import io
from glob import glob

# %%
wt_crop_dir = "../data-processed/crops/wt/"

imgs = sorted(glob(wt_crop_dir+"Image*.tif"))

# %%
imarrayRG = io.imread(imgs[-1])

print("dtype:{}, shape:{}, min:{}, max:{}".format(
    imarrayRG.dtype, imarrayRG.shape, imarrayRG.min(), imarrayRG.max()))

color = 'Reds'
name = 'VE-Cad'


R = imarrayRG[:,:,0]
## Plotting under this line ##
fig, ax = plt.subplots(figsize=(2,2))


ax.imshow(R, cmap=color)
ax.set_title(name)
ax.set_axis_off()
# Out:
# dtype:uint16, shape:(39, 30, 3), min:0, max:58112

# %%
from skimage.filters import threshold_otsu, threshold_local

val_otsu = threshold_otsu(R)
mask = R > val_otsu

print("otsu value:{}".format(val_otsu))

val_local = threshold_local(R, block_size=3)
mask_local = R > val_local
#fig, ax = filters.try_all_threshold(R)
#fig, ax = plt.subplots(figsize=(8,8))
#ax.imshow(mask)
#plt.show()

fig, ax = plt.subplots(figsize=(1,1))
ax.imshow(mask)
ax.axis('off')
# Out:
# otsu value:20736
# (-0.5, 29.5, 38.5, -0.5)

# %%
from skimage.filters import threshold_li

val_li = threshold_li(R)
mask = R > val_li

print("li value:{}".format(val_li))

fig, ax = plt.subplots(figsize=(1,1))
ax.imshow(mask)
ax.axis('off')
# Out:
# li value:11662.16433535146
# (-0.5, 29.5, 38.5, -0.5)

# %%
from skimage.morphology import binary_closing, erosion, opening

result = opening(mask)
fig, ax = plt.subplots(1,2, figsize=(3,3))
ax[0].imshow(result)
ax[1].imshow(R)
ax[0].axis('off')
ax[1].axis('off')
# Out:
# (-0.5, 29.5, 38.5, -0.5)

# %%
otsu_vals = []
li_vals = []
opened_results = []
img_arrays = []

otsu_means = []
li_means = []
opened_means = []
is_p120 = []
n = []

for img_file in imgs:
    is_p120.append("+" in img_file)
    img = io.imread(img_file)[:,:,0]
    img_arrays.append(img)
    
    temp_otsu_val = threshold_otsu(img)    
    temp_li_val = threshold_li(img)
    opened_result = opening(img > temp_li_val)
    
    otsu_mean = img[img > temp_otsu_val].mean()
    li_mean = img[img > temp_li_val].mean()
    opened_mean = img[opened_result].mean()
    
    otsu_means.append(otsu_mean)
    otsu_vals.append(temp_otsu_val)
    li_means.append(li_mean)
    li_vals.append(temp_li_val)
    opened_results.append(opened_result)
    opened_means.append(opened_mean)
    n.append(np.sum(opened_result))

is_p120 = np.asarray(is_p120)
opened_means = np.asarray(opened_means)
li_means = np.asarray(li_means)
n = np.asarray(n)

# %%
li_means
# Out:
# array([ 14001.65517241,  13228.67924528,  13454.46481876,  10955.29411765,
#          9537.59430605,  10269.18566775,   4449.97364259,   8042.76777251,
#          7868.26666667,   7123.16384181,  11057.4751773 ,   8321.43820225,
#         10162.50810811,   7115.35560505,   9445.18745831,   4879.47252747,
#          5465.46894198,   5082.31299735,  13708.84942085,  17794.50980392,
#         18081.42675159,  14511.93415638,  17127.94630872,  11422.08547009,
#          5964.92407108,   4765.13728964,   5568.52892562,   6236.21818182,
#          5403.19730185,   4435.54811715,   4590.50569476,   3938.10430839,
#          3997.14851485,  13905.58699187,  14520.88888889,  17623.39784946,
#          4562.91343284,   7328.78396437,  10801.79551122,   5962.29546947,
#          4807.0442953 ,   6139.50877193,  11212.48969697,  15710.16091954,
#         25961.22033898])

# %%
opened_means[~is_p120]
# Out:
# array([  5455.84678523,   8814.3022508 ,   9823.4095941 ,   6069.47945205,
#          6799.30170778,   6161.25067385,  13825.75945017,   8053.31714719,
#          6520.8259587 ,   6837.67741935,   8298.47094801,   7307.47169811,
#          5555.2       ,   5760.34688347,   4961.24675325,   5244.34285714,
#          6026.56880734,   9684.59130435,  13245.17269076,   8287.68190855,
#          5551.13078471])

# %%
def weighted_std(values, weights):
    weighted_avg = np.average(values, weights=weights)
    variance = np.average((values - weighted_avg)**2, weights=weights)
    return np.sqrt(variance)

# %%
p120_pos_std = weighted_std(opened_means[is_p120], weights = n[is_p120])

# %%
p120_neg_std =weighted_std(opened_means[~is_p120], weights = n[~is_p120])

# %%
np.average(opened_means[is_p120], weights = n[is_p120])
# Out:
# 13822.678237943535

# %%
np.average(opened_means[~is_p120], weights = n[~is_p120])
# Out:
# 7138.7946498819829

# %%
p120_pos_avg = np.average(opened_means[is_p120], weights = n[is_p120])
p120_neg_avg = np.average(opened_means[~is_p120], weights = n[~is_p120])

print("p120+ weighted avg intensity:{}".format(p120_pos_avg))
print("p120- weighted avg intensity:{}".format(p120_neg_avg))
# Out:
# p120+ weighted avg intensity:13822.678237943535
# p120- weighted avg intensity:7138.794649881983

# %%
print("p120+ unweighted avg intensity:{}".format(np.mean(opened_means[is_p120])))
print("p120- unweighted avg intensity:{}".format(np.mean(opened_means[~is_p120])))
# Out:
# p120+ unweighted avg intensity:14333.954221216483
# p120- unweighted avg intensity:7537.304527377488

# %%
fig, axes = plt.subplots(5,9, figsize=(12,12))
ax = axes.ravel()

for i, a in enumerate(ax):
    a.imshow(img_arrays[i] > li_means[i])
    a.set_title('{}'.format(i))
    a.axis('off')

# %%
fig, axes = plt.subplots(5,9, figsize=(12,12))
ax = axes.ravel()

for i, a in enumerate(ax):
    #a.imshow(img_arrays[i])
    a.imshow(opened_results[i])
    a.set_title('{}'.format(i))
    a.axis('off')

# %%
from statsmodels.stats.weightstats import ttest_ind

ttest_ind(opened_means[is_p120], opened_means[~is_p120],
         alternative='larger',
         usevar='unequal',
         weights = [n[is_p120], n[~is_p120]],
         value=0.)
# Out:
# (155.16847005980182, 0.0, 14814.824747968592)

# %%
## These means and stds are weighted
means = (p120_pos_avg, p120_neg_avg)
stds = (p120_pos_std, p120_neg_std)
ind = np.arange(len(means))
bar_names = ("p120+", "p120-")

p_pos, p_neg = plt.bar(ind, means, yerr=stds, capsize=4)

p_pos.set_facecolor('r')
plt.ylim([0, 28000])
plt.ylabel('Avg fluoresence intensity [a.u.]')
plt.title("VE-Cad Cell Border Intensities from \nVE-Cad-Cre_wt_flox-flox")
plt.xticks(ind, bar_names)
plt.savefig("../plots/bar_chart_ve-cad_border_intensities_VE-Cad-Cre_wt_flox-flox.png")
plt.savefig("../plots/bar_chart_ve-cad_border_intensities_VE-Cad-Cre_wt_flox-flox.pdf")

# %%
p120_neg_avg / p120_pos_avg
# Out:
# 0.51645524311532076

# %%
normed_neg_p120_avg = p120_neg_avg/p120_pos_avg * 100
normed_neg_p120_std = p120_neg_std/p120_pos_avg * 100

means = (normed_neg_p120_avg)
stds = (normed_neg_p120_std)
ind = np.arange(1)
#bar_names = ("")

p_neg = plt.bar(ind, means, yerr=stds, capsize=4)

plt.ylabel('% of wild type avg fluoresence intensity')
plt.title("VE-Cad Cell Border Intensities\nVE-Cad-Cre_wt_flox-flox")
plt.xticks(ind, "")
plt.ylim([0, 100])

plt.savefig("../plots/normalized_ve-cad-intensity_VE-Cad-Cre_wt_flox-flox.png")
plt.savefig("../plots/normalized_ve-cad-intensity_VE-Cad-Cre_wt_flox-flox.pdf")

# %%
total_pos = np.sum(n[is_p120] * opened_means[is_p120])
total_neg = np.sum(n[~is_p120] * opened_means[~is_p120])

# %%
len(n)
# Out:
# 45

# %%
normed_neg_p120_std
# Out:
# 15.059688997311763
